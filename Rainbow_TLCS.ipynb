# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuj1166/-Slidin-videos-Slide-Transition-Detection-and-Title-Extraction-in-Lecture-Video/blob/main/Rainbow_TLCS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Q-Learning for TLCS
#
# > Indented block
#
#
#
# **Author:** [Anuj braham]

# %%
# !pwd
# !ls
# !rm -r *
# !ls
# Out:
# /content
# sample_data

# %%
# !git clone "https://github.com/AndreaVidali/Deep-QLearning-Agent-for-Traffic-Signal-Control"
# Out:
# Cloning into 'Deep-QLearning-Agent-for-Traffic-Signal-Control'...
# remote: Enumerating objects: 193, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 193 (delta 1), reused 6 (delta 0), pack-reused 185
# Receiving objects: 100% (193/193), 179.37 KiB | 7.80 MiB/s, done.
# Resolving deltas: 100% (90/90), done.

# %%
# !mv /content/Deep-QLearning-Agent-for-Traffic-Signal-Control/TLCS/* /content/
# !rm -r Deep-QLearning-Agent-for-Traffic-Signal-Control

# %%
# !ls -l
# Out:
# total 72
# -rw-r--r-- 1 root root  5157 Jan 18 04:48 generator.py
# drwxr-xr-x 2 root root  4096 Jan 18 04:48 intersection
# -rw-r--r-- 1 root root   978 Jan 18 04:48 memory.py
# -rw-r--r-- 1 root root  3312 Jan 18 04:48 model.py
# -rw-r--r-- 1 root root  1752 Jan 18 04:48 testing_main.py
# -rw-r--r-- 1 root root   258 Jan 18 04:48 testing_settings.ini
# -rw-r--r-- 1 root root  8692 Jan 18 04:48 testing_simulation.py
# -rw-r--r-- 1 root root  2794 Jan 18 04:48 training_main.py
# -rw-r--r-- 1 root root   414 Jan 18 04:48 training_settings.ini
# -rw-r--r-- 1 root root 11990 Jan 18 04:48 training_simulation.py
# -rw-r--r-- 1 root root  4658 Jan 18 04:48 utils.py
# -rw-r--r-- 1 root root  1006 Jan 18 04:48 visualization.py

# %%
# !python --version
# Out:
# Python 3.8.16

# %%
# !add-apt-repository ppa:sumo/stable -y
# !apt-get update -y
# !apt-get install sumo sumo-tools sumo-doc
# Out:
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,622 B]
# Hit:6 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:7 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Hit:9 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:10 http://ppa.launchpad.net/sumo/stable/ubuntu bionic InRelease [15.4 kB]
# Ign:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# ...

# %%
# !pip install traci
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.7/262.7 KB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 KB 15.1 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['SUMO_HOME'] = "/usr/share/sumo/"

# %%
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 4/4 [==============================] - 0s 5ms/step
# Simulation time: 29.4 s - Training time: 191.4 s - Total: 220.8 s
#
# ----- Episode 99 of 100
#  Retrying in 1 seconds
# Simulating...
# ...
# 1/1 [==============================] - 0s 18ms/step
# ...
# ...
# 4/4 [==============================] - 0s 5ms/step
# Simulation time: 29.3 s - Training time: 190.9 s - Total: 220.2 s
#
# ----- Start time: 2023-01-18 04:49:00.447584
# ----- End time: 2023-01-18 10:33:07.284328
# ----- Session info saved at: /content/models/model_1/

# %%
# !cp -r models /content/drive/MyDrive
